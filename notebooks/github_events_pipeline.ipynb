# %%
import os
import dlt
from oss_analytics.source.github_source import paginated_getter
from dotenv import load_dotenv
import duckdb

load_dotenv()
github_token = os.getenv("GITHUB_TOKEN")

# %% [markdown]
# ### ingestion

# %%
pipeline = dlt.pipeline(
        pipeline_name="github_pipeline",
        destination="duckdb",
        dataset_name="events_dataset",
    )

run_info = pipeline.run(
    paginated_getter(
        repo="supabase/supabase",
        endpoint="events",
        token=github_token
    ),
    table_name="events",
    write_disposition="replace",
)
# Out:
# 2025-06-20 10:39:00,560|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__issue__assignee in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__issue__assignee': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,560|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__issue__milestone in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__issue__milestone': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,561|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__issue__type in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__issue__type': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,561|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__issue__active_lock_reason in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__issue__active_lock_reason': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,561|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__issue__pull_request__merged_at in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__issue__pull_request__merged_at': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,561|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__issue__performed_via_github_app in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__issue__performed_via_github_app': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,562|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__pull_request__assignee in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__pull_request__assignee': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,562|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__pull_request__milestone in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__pull_request__milestone': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,562|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__pull_request__head__repo__mirror_url in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__pull_request__head__repo__mirror_url': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,562|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__pull_request__base__repo__mirror_url in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__pull_request__base__repo__mirror_url': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,562|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__pull_request__auto_merge in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__pull_request__auto_merge': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,562|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__pull_request__active_lock_reason in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__pull_request__active_lock_reason': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,562|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__pull_request__merged_by in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__pull_request__merged_by': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,563|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__forkee__language in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__forkee__language': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,563|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__forkee__mirror_url in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__forkee__mirror_url': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,563|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__forkee__license in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__forkee__license': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,563|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__comment__start_line in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__comment__start_line': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,564|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__comment__original_start_line in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__comment__original_start_line': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,564|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__comment__start_side in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__comment__start_side': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,564|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column payload__comment__performed_via_github_app in table events did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'payload__comment__performed_via_github_app': {'data_type': 'text'}})
#
#
# 2025-06-20 10:39:00,564|[WARNING]|84965|126141483695168|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column parent in table events__payload__pull_request__requested_teams did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'parent': {'data_type': 'text'}})

# %% [markdown]
# ### Database inspections
# - table_names
# - table df
# - pipeline.sql_client()
# - dlt pipeline
#   - _dlt_pipeline_state
#   - _dlt_loads
#   - _dlt_version
# - DuckDB
#   - list of tables: FROM information_schema.tables
#   - df: FROM events_dataset.events

# %%
print(pipeline.dataset(dataset_type="default").schema.data_table_names())
# Out:
# ['events', 'events__payload__commits', 'events__payload__pull_request__head__repo__topics', 'events__payload__pull_request__base__repo__topics', 'events__payload__comment__performed_via_github_app__events', 'events__payload__issue__labels', 'events__payload__issue__assignees', 'events__payload__pull_request__assignees', 'events__payload__pull_request__requested_reviewers', 'events__payload__pull_request__labels', 'events__payload__release__mentions', 'events__payload__pull_request__requested_teams']

# %%
pipeline.dataset(dataset_type="default").events.df().head()
# Out:
#             id               type  actor__id actor__login  \
# 0  51094393247          PushEvent   19742402    joshenlim
# 1  51094317768          PushEvent   37541088     jordienr
# 2  51094089084         WatchEvent   22812353      hktklxz
# 3  51093887562  IssueCommentEvent   35613825  vercel[bot]
# 4  51093881002   PullRequestEvent   19742402    joshenlim
#
#   actor__display_login actor__gravatar_id  \
# 0            joshenlim
# 1             jordienr
# 2              hktklxz
# 3               vercel
# 4            joshenlim
#
#                                  actor__url  \
# 0    https://api.github.com/users/joshenlim
# 1     https://api.github.com/users/jordienr
# 2      https://api.github.com/users/hktklxz
# 3  https://api.github.com/users/vercel[bot]
# 4    https://api.github.com/users/joshenlim
#
#                                    actor__avatar_url   repo__id  \
# 0  https://avatars.githubusercontent.com/u/19742402?  214587193
# 1  https://avatars.githubusercontent.com/u/37541088?  214587193
# 2  https://avatars.githubusercontent.com/u/22812353?  214587193
# 3  https://avatars.githubusercontent.com/u/35613825?  214587193
# 4  https://avatars.githubusercontent.com/u/19742402?  214587193
#
#           repo__name  ...  \
# 0  supabase/supabase  ...
# 1  supabase/supabase  ...
# 2  supabase/supabase  ...
# 3  supabase/supabase  ...
# 4  supabase/supabase  ...
#
#   payload__comment__performed_via_github_app__permissions__attestations  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#    payload__comment__performed_via_github_app__permissions__discussions  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#    payload__comment__performed_via_github_app__permissions__merge_queues  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#    payload__comment__performed_via_github_app__permissions__models  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#    payload__comment__performed_via_github_app__permissions__packages  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   payload__comment__performed_via_github_app__permissions__pages  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   payload__comment__performed_via_github_app__permissions__repository_projects  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   payload__comment__performed_via_github_app__permissions__security_events  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#    payload__comment__performed_via_github_app__permissions__vulnerability_alerts  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   payload__issue__pull_request__merged_at
# 0                                     NaT
# 1                                     NaT
# 2                                     NaT
# 3                                     NaT
# 4                                     NaT
#
# [5 rows x 757 columns]

# %%
pipeline.dataset(dataset_type="default").events.df().shape
# Out:
# (278, 757)

# %%
sql = """
SELECT *
FROM events e
JOIN events__payload__pull_request__base__repo__topics c
ON e._dlt_id = c._dlt_parent_id
"""
with pipeline.sql_client() as client:
    with client.execute_query(sql) as cursor:
        data = cursor.df()
data
# Out:
#                                                  name
# 0                                          _dlt_loads
# 1                                 _dlt_pipeline_state
# 2                                        _dlt_version
# 3                                              events
# 4   events__payload__comment__performed_via_github...
# 5                            events__payload__commits
# 6                   events__payload__issue__assignees
# 7                      events__payload__issue__labels
# 8            events__payload__pull_request__assignees
# 9   events__payload__pull_request__base__repo__topics
# 10  events__payload__pull_request__head__repo__topics
# 11              events__payload__pull_request__labels
# 12  events__payload__pull_request__requested_revie...
# 13     events__payload__pull_request__requested_teams
# 14                 events__payload__release__mentions

# %%
pipeline.dataset(dataset_type="default")._dlt_pipeline_state.df()
# Out:
#    version  engine_version    pipeline_name  \
# 0        1               4  github_pipeline
#
#                                                state  \
# 0  eNpdj1FrwkAQhP/LvhrEghoM+KDUUrDqa2spxyXZmmsvl5...
#
#                         created_at  \
# 0 2025-06-19 09:12:48.066185+00:00
#
#                                    version_hash       _dlt_load_id  \
# 0  6MOXBOD7z7mLw9Y5Ke+Mljo7vEEymZrFNwHx50AcK6A=  1750324361.488451
#
#           _dlt_id
# 0  N/87pgUi4lLHIg

# %%
pipeline.dataset(dataset_type="default")._dlt_loads.df()
# Out:
#              load_id schema_name  status                      inserted_at  \
# 0  1750324361.488451      github       0 2025-06-19 09:12:49.604073+00:00
# 1  1750324555.113997      github       0 2025-06-19 09:16:03.746041+00:00
#
#                             schema_version_hash
# 0  GmYMyAjUwhFJbnbfHxlD5mCToZNSZDQrL7vN3aqkAv0=
# 1  K4L2LSS1hk8vJA3SjtQQzA84Etv2zyy597DDjG1viaM=

# %%
pipeline.dataset(dataset_type="default")._dlt_version.df()
# Out:
#    version  engine_version                      inserted_at schema_name  \
# 0        2              11 2025-06-19 09:12:48.378930+00:00      github
# 1        3              11 2025-06-19 09:16:02.581367+00:00      github
#
#                                    version_hash  \
# 0  GmYMyAjUwhFJbnbfHxlD5mCToZNSZDQrL7vN3aqkAv0=
# 1  K4L2LSS1hk8vJA3SjtQQzA84Etv2zyy597DDjG1viaM=
#
#                                               schema
# 0  {"version":2,"version_hash":"GmYMyAjUwhFJbnbfH...
# 1  {"version":3,"version_hash":"K4L2LSS1hk8vJA3Sj...

# %%
conn = duckdb.connect('github_pipeline.duckdb')

sql = """
SELECT *
FROM information_schema.tables
"""
conn.execute(sql).df()
# Out:
#       table_catalog    table_schema  \
# 0   github_pipeline  events_dataset
# 1   github_pipeline  events_dataset
# 2   github_pipeline  events_dataset
# 3   github_pipeline  events_dataset
# 4   github_pipeline  events_dataset
# 5   github_pipeline  events_dataset
# 6   github_pipeline  events_dataset
# 7   github_pipeline  events_dataset
# 8   github_pipeline  events_dataset
# 9   github_pipeline  events_dataset
# 10  github_pipeline  events_dataset
# 11  github_pipeline  events_dataset
#
#                                            table_name  table_type  \
# 0                                              events  BASE TABLE
# 1   events__payload__comment__performed_via_github...  BASE TABLE
# 2                            events__payload__commits  BASE TABLE
# 3                      events__payload__issue__labels  BASE TABLE
# 4   events__payload__pull_request__base__repo__topics  BASE TABLE
# 5   events__payload__pull_request__head__repo__topics  BASE TABLE
# 6               events__payload__pull_request__labels  BASE TABLE
# 7   events__payload__pull_request__requested_revie...  BASE TABLE
# 8      events__payload__pull_request__requested_teams  BASE TABLE
# 9                                          _dlt_loads  BASE TABLE
# 10                                _dlt_pipeline_state  BASE TABLE
# 11                                       _dlt_version  BASE TABLE
#
#    self_referencing_column_name reference_generation  \
# 0                          None                 None
# 1                          None                 None
# 2                          None                 None
# 3                          None                 None
# 4                          None                 None
# 5                          None                 None
# 6                          None                 None
# 7                          None                 None
# 8                          None                 None
# 9                          None                 None
# 10                         None                 None
# 11                         None                 None
#
#    user_defined_type_catalog user_defined_type_schema user_defined_type_name  \
# 0                       None                     None                   None
# 1                       None                     None                   None
# 2                       None                     None                   None
# 3                       None                     None                   None
# 4                       None                     None                   None
# 5                       None                     None                   None
# 6                       None                     None                   None
# 7                       None                     None                   None
# 8                       None                     None                   None
# 9                       None                     None                   None
# 10                      None                     None                   None
# 11                      None                     None                   None
#
#    is_insertable_into is_typed commit_action TABLE_COMMENT
# 0                 YES       NO          None          None
# 1                 YES       NO          None          None
# 2                 YES       NO          None          None
# 3                 YES       NO          None          None
# 4                 YES       NO          None          None
# 5                 YES       NO          None          None
# 6                 YES       NO          None          None
# 7                 YES       NO          None          None
# 8                 YES       NO          None          None
# 9                 YES       NO          None          None
# 10                YES       NO          None          None
# 11                YES       NO          None          None

# %%
sql = """
SELECT *
FROM events_dataset.events
"""
conn.execute(sql).df()
# Out:
#               id               type  actor__id   actor__login  \
# 0    51128078967  IssueCommentEvent  132864931  supabase[bot]
# 1    51128078733  IssueCommentEvent   35613825    vercel[bot]
# 2    51128077376   PullRequestEvent   19742402      joshenlim
# 3    51128053273        CreateEvent   19742402      joshenlim
# 4    51127943160         WatchEvent     412511     Siliconrob
# ..           ...                ...        ...            ...
# 276  51028020694  IssueCommentEvent   35613825    vercel[bot]
# 277  51028018489   PullRequestEvent   26616127      charislam
# 278  51028006353          PushEvent   26616127      charislam
# 279  51027983583        CreateEvent   26616127      charislam
# 280  51027676720          PushEvent   12958657        olirice
#
#     actor__display_login actor__gravatar_id  \
# 0               supabase
# 1                 vercel
# 2              joshenlim
# 3              joshenlim
# 4             Siliconrob
# ..                   ...                ...
# 276               vercel
# 277            charislam
# 278            charislam
# 279            charislam
# 280              olirice
#
#                                      actor__url  \
# 0    https://api.github.com/users/supabase[bot]
# 1      https://api.github.com/users/vercel[bot]
# 2        https://api.github.com/users/joshenlim
# 3        https://api.github.com/users/joshenlim
# 4       https://api.github.com/users/Siliconrob
# ..                                          ...
# 276    https://api.github.com/users/vercel[bot]
# 277      https://api.github.com/users/charislam
# 278      https://api.github.com/users/charislam
# 279      https://api.github.com/users/charislam
# 280        https://api.github.com/users/olirice
#
#                                      actor__avatar_url   repo__id  \
# 0    https://avatars.githubusercontent.com/u/132864...  214587193
# 1    https://avatars.githubusercontent.com/u/35613825?  214587193
# 2    https://avatars.githubusercontent.com/u/19742402?  214587193
# 3    https://avatars.githubusercontent.com/u/19742402?  214587193
# 4      https://avatars.githubusercontent.com/u/412511?  214587193
# ..                                                 ...        ...
# 276  https://avatars.githubusercontent.com/u/35613825?  214587193
# 277  https://avatars.githubusercontent.com/u/26616127?  214587193
# 278  https://avatars.githubusercontent.com/u/26616127?  214587193
# 279  https://avatars.githubusercontent.com/u/26616127?  214587193
# 280  https://avatars.githubusercontent.com/u/12958657?  214587193
#
#             repo__name  ...  \
# 0    supabase/supabase  ...
# 1    supabase/supabase  ...
# 2    supabase/supabase  ...
# 3    supabase/supabase  ...
# 4    supabase/supabase  ...
# ..                 ...  ...
# 276  supabase/supabase  ...
# 277  supabase/supabase  ...
# 278  supabase/supabase  ...
# 279  supabase/supabase  ...
# 280  supabase/supabase  ...
#
#     payload__pull_request__auto_merge__enabled_by__type  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 276                                               None
# 277                                               None
# 278                                               None
# 279                                               None
# 280                                               None
#
#     payload__pull_request__auto_merge__enabled_by__user_view_type  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 276                                               None
# 277                                               None
# 278                                               None
# 279                                               None
# 280                                               None
#
#     payload__pull_request__auto_merge__enabled_by__site_admin  \
# 0                                                 <NA>
# 1                                                 <NA>
# 2                                                 <NA>
# 3                                                 <NA>
# 4                                                 <NA>
# ..                                                 ...
# 276                                               <NA>
# 277                                               <NA>
# 278                                               <NA>
# 279                                               <NA>
# 280                                               <NA>
#
#     payload__pull_request__auto_merge__merge_method  \
# 0                                              None
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                              None
# ..                                              ...
# 276                                            None
# 277                                            None
# 278                                            None
# 279                                            None
# 280                                            None
#
#     payload__pull_request__auto_merge__commit_title  \
# 0                                              None
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                              None
# ..                                              ...
# 276                                            None
# 277                                            None
# 278                                            None
# 279                                            None
# 280                                            None
#
#     payload__pull_request__auto_merge__commit_message payload__review__body  \
# 0                                                None                  None
# 1                                                None                  None
# 2                                                None                  None
# 3                                                None                  None
# 4                                                None                  None
# ..                                                ...                   ...
# 276                                              None                  None
# 277                                              None                  None
# 278                                              None                  None
# 279                                              None                  None
# 280                                              None                  None
#
#     payload__comment__in_reply_to_id  payload__pull_request__mergeable  \
# 0                               <NA>                              <NA>
# 1                               <NA>                              <NA>
# 2                               <NA>                              <NA>
# 3                               <NA>                              <NA>
# 4                               <NA>                              <NA>
# ..                               ...                               ...
# 276                             <NA>                              <NA>
# 277                             <NA>                              True
# 278                             <NA>                              <NA>
# 279                             <NA>                              <NA>
# 280                             <NA>                              <NA>
#
#     payload__pull_request__rebaseable
# 0                                <NA>
# 1                                <NA>
# 2                                <NA>
# 3                                <NA>
# 4                                <NA>
# ..                                ...
# 276                              <NA>
# 277                              True
# 278                              <NA>
# 279                              <NA>
# 280                              <NA>
#
# [281 rows x 655 columns]

# %%
pipeline = dlt.pipeline(
        pipeline_name="github_pipeline",
        destination="duckdb",
        dataset_name="commits_dataset",
    )

run_info = pipeline.run(
    paginated_getter(
        repo="supabase/supabase",
        endpoint="commits",
        token=github_token
    ),
    table_name="commits",
    write_disposition="replace",
)
# Out:
# 2025-06-20 11:30:19,117|[WARNING]|8233|129979985632320|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column author in table commits did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'author': {'data_type': 'text'}})
#
#
# 2025-06-20 11:30:19,117|[WARNING]|8233|129979985632320|dlt|validate.py|verify_normalized_table:48|In schema `github`: The column committer in table commits did not receive any data during this load. Therefore, its type couldn't be inferred. Unless a type hint is provided, the column will not be materialized in the destination. One way to provide a type hint is to use the 'columns' argument in the '@dlt.resource' decorator. For example:
#
# @dlt.resource(columns={'committer': {'data_type': 'text'}})

# %%
conn = duckdb.connect('github_pipeline.duckdb')

sql = """
SELECT *
FROM information_schema.tables
"""
conn.execute(sql).df()
# Out:
#       table_catalog     table_schema  \
# 0   github_pipeline  commits_dataset
# 1   github_pipeline  commits_dataset
# 2   github_pipeline  commits_dataset
# 3   github_pipeline  commits_dataset
# 4   github_pipeline  commits_dataset
# 5   github_pipeline   events_dataset
# 6   github_pipeline   events_dataset
# 7   github_pipeline   events_dataset
# 8   github_pipeline   events_dataset
# 9   github_pipeline   events_dataset
# 10  github_pipeline   events_dataset
# 11  github_pipeline   events_dataset
# 12  github_pipeline   events_dataset
# 13  github_pipeline   events_dataset
# 14  github_pipeline   events_dataset
# 15  github_pipeline   events_dataset
# 16  github_pipeline   events_dataset
#
#                                            table_name  table_type  \
# 0                                             commits  BASE TABLE
# 1                                    commits__parents  BASE TABLE
# 2                                          _dlt_loads  BASE TABLE
# 3                                 _dlt_pipeline_state  BASE TABLE
# 4                                        _dlt_version  BASE TABLE
# 5                                              events  BASE TABLE
# 6   events__payload__comment__performed_via_github...  BASE TABLE
# 7                            events__payload__commits  BASE TABLE
# 8                      events__payload__issue__labels  BASE TABLE
# 9   events__payload__pull_request__base__repo__topics  BASE TABLE
# 10  events__payload__pull_request__head__repo__topics  BASE TABLE
# 11              events__payload__pull_request__labels  BASE TABLE
# 12  events__payload__pull_request__requested_revie...  BASE TABLE
# 13     events__payload__pull_request__requested_teams  BASE TABLE
# 14                                         _dlt_loads  BASE TABLE
# 15                                _dlt_pipeline_state  BASE TABLE
# 16                                       _dlt_version  BASE TABLE
#
#    self_referencing_column_name reference_generation  \
# 0                          None                 None
# 1                          None                 None
# 2                          None                 None
# 3                          None                 None
# 4                          None                 None
# 5                          None                 None
# 6                          None                 None
# 7                          None                 None
# 8                          None                 None
# 9                          None                 None
# 10                         None                 None
# 11                         None                 None
# 12                         None                 None
# 13                         None                 None
# 14                         None                 None
# 15                         None                 None
# 16                         None                 None
#
#    user_defined_type_catalog user_defined_type_schema user_defined_type_name  \
# 0                       None                     None                   None
# 1                       None                     None                   None
# 2                       None                     None                   None
# 3                       None                     None                   None
# 4                       None                     None                   None
# 5                       None                     None                   None
# 6                       None                     None                   None
# 7                       None                     None                   None
# 8                       None                     None                   None
# 9                       None                     None                   None
# 10                      None                     None                   None
# 11                      None                     None                   None
# 12                      None                     None                   None
# 13                      None                     None                   None
# 14                      None                     None                   None
# 15                      None                     None                   None
# 16                      None                     None                   None
#
#    is_insertable_into is_typed commit_action TABLE_COMMENT
# 0                 YES       NO          None          None
# 1                 YES       NO          None          None
# 2                 YES       NO          None          None
# 3                 YES       NO          None          None
# 4                 YES       NO          None          None
# 5                 YES       NO          None          None
# 6                 YES       NO          None          None
# 7                 YES       NO          None          None
# 8                 YES       NO          None          None
# 9                 YES       NO          None          None
# 10                YES       NO          None          None
# 11                YES       NO          None          None
# 12                YES       NO          None          None
# 13                YES       NO          None          None
# 14                YES       NO          None          None
# 15                YES       NO          None          None
# 16                YES       NO          None          None

# %%
sql = """
SELECT *
FROM commits_dataset.commits
"""
df = conn.execute(sql).df()
df
# Out:
#                                             sha  \
# 0      7cc64d3bd174c00ca61cf1f746a48bf22bcaff54
# 1      5cc2617b5f8eeb361e9e5b7f7084109188298714
# 2      380a55e9bf8b6e49157f28f5dc4466d505cf1658
# 3      b1ad7649f3dd5c8cb571e51e33e14266e3f4b1f0
# 4      058b25d7c30a33787e5ea3e5ea7f071c036b4362
# ...                                         ...
# 31656  3951357072668f330c1acaa1ad11aea2d89b81ee
# 31657  cb24db899d07fbe83c734b0e18f7d9d618904b3b
# 31658  bec67900fa9e0a4b2892d69f8f4968d3c344121b
# 31659  ff6a1d151783d0e07aec2b40c6950817ef03f09f
# 31660  1a374516deead12f0b737f4886c07be5b647d24a
#
#                                                  node_id  \
# 0      C_kwDODMpXOdoAKDdjYzY0ZDNiZDE3NGMwMGNhNjFjZjFm...
# 1      C_kwDODMpXOdoAKDVjYzI2MTdiNWY4ZWViMzYxZTllNWI3...
# 2      C_kwDODMpXOdoAKDM4MGE1NWU5YmY4YjZlNDkxNTdmMjhm...
# 3      C_kwDODMpXOdoAKGIxYWQ3NjQ5ZjNkZDVjOGNiNTcxZTUx...
# 4      C_kwDODMpXOdoAKDA1OGIyNWQ3YzMwYTMzNzg3ZTVlYTNl...
# ...                                                  ...
# 31656  MDY6Q29tbWl0MjE0NTg3MTkzOjM5NTEzNTcwNzI2NjhmMz...
# 31657  MDY6Q29tbWl0MjE0NTg3MTkzOmNiMjRkYjg5OWQwN2ZiZT...
# 31658  MDY6Q29tbWl0MjE0NTg3MTkzOmJlYzY3OTAwZmE5ZTBhNG...
# 31659  MDY6Q29tbWl0MjE0NTg3MTkzOmZmNmExZDE1MTc4M2QwZT...
# 31660  MDY6Q29tbWl0MjE0NTg3MTkzOjFhMzc0NTE2ZGVlYWQxMm...
#
#          commit__author__name                           commit__author__email  \
# 0                      Charis     26616127+charislam@users.noreply.github.com
# 1                      Charis     26616127+charislam@users.noreply.github.com
# 2               Tristan Smith  67556218+TJLSmith0831@users.noreply.github.com
# 3      Francesco Sansalvadore                        f.sansalvadore@gmail.com
# 4             Kevin Grüneberg                      k.grueneberg1994@gmail.com
# ...                       ...                                             ...
# 31656        Paul Copplestone                          pcopplestone@gmail.com
# 31657        Paul Copplestone                          pcopplestone@gmail.com
# 31658        Paul Copplestone                          pcopplestone@gmail.com
# 31659        Paul Copplestone                          pcopplestone@gmail.com
# 31660        Paul Copplestone                          pcopplestone@gmail.com
#
#            commit__author__date commit__committer__name  \
# 0     2025-06-19 18:14:29+00:00                  GitHub
# 1     2025-06-19 14:54:43+00:00                  GitHub
# 2     2025-06-19 13:53:53+00:00                  GitHub
# 3     2025-06-19 11:01:41+00:00                  GitHub
# 4     2025-06-19 03:34:52+00:00                  GitHub
# ...                         ...                     ...
# 31656 2019-10-12 08:55:38+00:00        Paul Copplestone
# 31657 2019-10-12 07:05:05+00:00        Paul Copplestone
# 31658 2019-10-12 06:35:30+00:00        Paul Copplestone
# 31659 2019-10-12 06:33:00+00:00        Paul Copplestone
# 31660 2019-10-12 04:53:09+00:00        Paul Copplestone
#
#       commit__committer__email   commit__committer__date  \
# 0           noreply@github.com 2025-06-19 18:14:29+00:00
# 1           noreply@github.com 2025-06-19 14:54:43+00:00
# 2           noreply@github.com 2025-06-19 13:53:53+00:00
# 3           noreply@github.com 2025-06-19 11:01:41+00:00
# 4           noreply@github.com 2025-06-19 03:34:52+00:00
# ...                        ...                       ...
# 31656   pcopplestone@gmail.com 2019-10-12 08:55:38+00:00
# 31657   pcopplestone@gmail.com 2019-10-12 07:05:05+00:00
# 31658   pcopplestone@gmail.com 2019-10-12 06:35:30+00:00
# 31659   pcopplestone@gmail.com 2019-10-12 06:33:00+00:00
# 31660   pcopplestone@gmail.com 2019-10-12 04:53:09+00:00
#
#                                          commit__message  \
# 0      docs(edge functions): document that sentry nee...
# 1      fix(docs): add more descriptive error message ...
# 2      docs: clarify that migrations must be applied ...
# 3      db report (#36516)\n\n* release new charts to ...
# 4      chore: show org error message for longer (#36526)
# ...                                                  ...
# 31656                   fat fingered typo for build:docs
# 31657                       Adding netlify deploy config
# 31658                                      Hiding signup
# 31659                                Adding sign up form
# 31660                                      Init monorepo
#
#                               commit__tree__sha  ...  \
# 0      6dc16061a3641ac99db060107f23e09fa8d118f3  ...
# 1      5904a3f4257c677b0f327ccd7265eb43c1c5b648  ...
# 2      bd058e1c5fc6a35f320e0138510be16c768b6690  ...
# 3      0a3861a1fb57e355e0acb8907fd9ff5dcda5dadb  ...
# 4      01bfe4a2e97efc6e89c62802abbbb35fe771f329  ...
# ...                                         ...  ...
# 31656  680248454dcdbe5b0f73495d7ca0bafd37ce6f4a  ...
# 31657  2f303fc61187989bb1ea96cc0bf819dc7ac18605  ...
# 31658  0c436efcbec30afbcd81e3b820dd0ed5691e2d9d  ...
# 31659  de0891add3037438686b57961564c30ee04dba8c  ...
# 31660  ab0e8bbc38a6ef95bd1f2c6d3d962acc55623dd3  ...
#
#                             committer__subscriptions_url  \
# 0      https://api.github.com/users/web-flow/subscrip...
# 1      https://api.github.com/users/web-flow/subscrip...
# 2      https://api.github.com/users/web-flow/subscrip...
# 3      https://api.github.com/users/web-flow/subscrip...
# 4      https://api.github.com/users/web-flow/subscrip...
# ...                                                  ...
# 31656  https://api.github.com/users/kiwicopple/subscr...
# 31657  https://api.github.com/users/kiwicopple/subscr...
# 31658  https://api.github.com/users/kiwicopple/subscr...
# 31659  https://api.github.com/users/kiwicopple/subscr...
# 31660  https://api.github.com/users/kiwicopple/subscr...
#
#                        committer__organizations_url  \
# 0        https://api.github.com/users/web-flow/orgs
# 1        https://api.github.com/users/web-flow/orgs
# 2        https://api.github.com/users/web-flow/orgs
# 3        https://api.github.com/users/web-flow/orgs
# 4        https://api.github.com/users/web-flow/orgs
# ...                                             ...
# 31656  https://api.github.com/users/kiwicopple/orgs
# 31657  https://api.github.com/users/kiwicopple/orgs
# 31658  https://api.github.com/users/kiwicopple/orgs
# 31659  https://api.github.com/users/kiwicopple/orgs
# 31660  https://api.github.com/users/kiwicopple/orgs
#
#                                 committer__repos_url  \
# 0        https://api.github.com/users/web-flow/repos
# 1        https://api.github.com/users/web-flow/repos
# 2        https://api.github.com/users/web-flow/repos
# 3        https://api.github.com/users/web-flow/repos
# 4        https://api.github.com/users/web-flow/repos
# ...                                              ...
# 31656  https://api.github.com/users/kiwicopple/repos
# 31657  https://api.github.com/users/kiwicopple/repos
# 31658  https://api.github.com/users/kiwicopple/repos
# 31659  https://api.github.com/users/kiwicopple/repos
# 31660  https://api.github.com/users/kiwicopple/repos
#
#                                    committer__events_url  \
# 0      https://api.github.com/users/web-flow/events{/...
# 1      https://api.github.com/users/web-flow/events{/...
# 2      https://api.github.com/users/web-flow/events{/...
# 3      https://api.github.com/users/web-flow/events{/...
# 4      https://api.github.com/users/web-flow/events{/...
# ...                                                  ...
# 31656  https://api.github.com/users/kiwicopple/events...
# 31657  https://api.github.com/users/kiwicopple/events...
# 31658  https://api.github.com/users/kiwicopple/events...
# 31659  https://api.github.com/users/kiwicopple/events...
# 31660  https://api.github.com/users/kiwicopple/events...
#
#                           committer__received_events_url committer__type  \
# 0      https://api.github.com/users/web-flow/received...            User
# 1      https://api.github.com/users/web-flow/received...            User
# 2      https://api.github.com/users/web-flow/received...            User
# 3      https://api.github.com/users/web-flow/received...            User
# 4      https://api.github.com/users/web-flow/received...            User
# ...                                                  ...             ...
# 31656  https://api.github.com/users/kiwicopple/receiv...            User
# 31657  https://api.github.com/users/kiwicopple/receiv...            User
# 31658  https://api.github.com/users/kiwicopple/receiv...            User
# 31659  https://api.github.com/users/kiwicopple/receiv...            User
# 31660  https://api.github.com/users/kiwicopple/receiv...            User
#
#       committer__user_view_type committer__site_admin        _dlt_load_id  \
# 0                        public                 False  1750393271.2874556
# 1                        public                 False  1750393271.2874556
# 2                        public                 False  1750393271.2874556
# 3                        public                 False  1750393271.2874556
# 4                        public                 False  1750393271.2874556
# ...                         ...                   ...                 ...
# 31656                    public                 False  1750393271.2874556
# 31657                    public                 False  1750393271.2874556
# 31658                    public                 False  1750393271.2874556
# 31659                    public                 False  1750393271.2874556
# 31660                    public                 False  1750393271.2874556
#
#               _dlt_id
# 0      xMYALiukkZ4NPQ
# 1      +ReRupwwV0r3pA
# 2      0hkd+G0yp8gDdg
# 3      Psyg40XK3sfqXA
# 4      HQYfluh6zK9xLA
# ...               ...
# 31656  0VH1zFjLK3t4Cg
# 31657  6y0UnTmfmyVClQ
# 31658  uM7dy9h8To6Fiw
# 31659  eyUb1+T4y7Oh+g
# 31660  5xIr1IBAEfR3og
#
# [31661 rows x 61 columns]

# %% [markdown]
# ### commits dataset

# %%
df.head()
# Out:
#                                         sha  \
# 0  7cc64d3bd174c00ca61cf1f746a48bf22bcaff54
# 1  5cc2617b5f8eeb361e9e5b7f7084109188298714
# 2  380a55e9bf8b6e49157f28f5dc4466d505cf1658
# 3  b1ad7649f3dd5c8cb571e51e33e14266e3f4b1f0
# 4  058b25d7c30a33787e5ea3e5ea7f071c036b4362
#
#                                              node_id    commit__author__name  \
# 0  C_kwDODMpXOdoAKDdjYzY0ZDNiZDE3NGMwMGNhNjFjZjFm...                  Charis
# 1  C_kwDODMpXOdoAKDVjYzI2MTdiNWY4ZWViMzYxZTllNWI3...                  Charis
# 2  C_kwDODMpXOdoAKDM4MGE1NWU5YmY4YjZlNDkxNTdmMjhm...           Tristan Smith
# 3  C_kwDODMpXOdoAKGIxYWQ3NjQ5ZjNkZDVjOGNiNTcxZTUx...  Francesco Sansalvadore
# 4  C_kwDODMpXOdoAKDA1OGIyNWQ3YzMwYTMzNzg3ZTVlYTNl...         Kevin Grüneberg
#
#                             commit__author__email      commit__author__date  \
# 0     26616127+charislam@users.noreply.github.com 2025-06-19 18:14:29+00:00
# 1     26616127+charislam@users.noreply.github.com 2025-06-19 14:54:43+00:00
# 2  67556218+TJLSmith0831@users.noreply.github.com 2025-06-19 13:53:53+00:00
# 3                        f.sansalvadore@gmail.com 2025-06-19 11:01:41+00:00
# 4                      k.grueneberg1994@gmail.com 2025-06-19 03:34:52+00:00
#
#   commit__committer__name commit__committer__email   commit__committer__date  \
# 0                  GitHub       noreply@github.com 2025-06-19 18:14:29+00:00
# 1                  GitHub       noreply@github.com 2025-06-19 14:54:43+00:00
# 2                  GitHub       noreply@github.com 2025-06-19 13:53:53+00:00
# 3                  GitHub       noreply@github.com 2025-06-19 11:01:41+00:00
# 4                  GitHub       noreply@github.com 2025-06-19 03:34:52+00:00
#
#                                      commit__message  \
# 0  docs(edge functions): document that sentry nee...
# 1  fix(docs): add more descriptive error message ...
# 2  docs: clarify that migrations must be applied ...
# 3  db report (#36516)\n\n* release new charts to ...
# 4  chore: show org error message for longer (#36526)
#
#                           commit__tree__sha  ...  \
# 0  6dc16061a3641ac99db060107f23e09fa8d118f3  ...
# 1  5904a3f4257c677b0f327ccd7265eb43c1c5b648  ...
# 2  bd058e1c5fc6a35f320e0138510be16c768b6690  ...
# 3  0a3861a1fb57e355e0acb8907fd9ff5dcda5dadb  ...
# 4  01bfe4a2e97efc6e89c62802abbbb35fe771f329  ...
#
#                         committer__subscriptions_url  \
# 0  https://api.github.com/users/web-flow/subscrip...
# 1  https://api.github.com/users/web-flow/subscrip...
# 2  https://api.github.com/users/web-flow/subscrip...
# 3  https://api.github.com/users/web-flow/subscrip...
# 4  https://api.github.com/users/web-flow/subscrip...
#
#                  committer__organizations_url  \
# 0  https://api.github.com/users/web-flow/orgs
# 1  https://api.github.com/users/web-flow/orgs
# 2  https://api.github.com/users/web-flow/orgs
# 3  https://api.github.com/users/web-flow/orgs
# 4  https://api.github.com/users/web-flow/orgs
#
#                           committer__repos_url  \
# 0  https://api.github.com/users/web-flow/repos
# 1  https://api.github.com/users/web-flow/repos
# 2  https://api.github.com/users/web-flow/repos
# 3  https://api.github.com/users/web-flow/repos
# 4  https://api.github.com/users/web-flow/repos
#
#                                committer__events_url  \
# 0  https://api.github.com/users/web-flow/events{/...
# 1  https://api.github.com/users/web-flow/events{/...
# 2  https://api.github.com/users/web-flow/events{/...
# 3  https://api.github.com/users/web-flow/events{/...
# 4  https://api.github.com/users/web-flow/events{/...
#
#                       committer__received_events_url committer__type  \
# 0  https://api.github.com/users/web-flow/received...            User
# 1  https://api.github.com/users/web-flow/received...            User
# 2  https://api.github.com/users/web-flow/received...            User
# 3  https://api.github.com/users/web-flow/received...            User
# 4  https://api.github.com/users/web-flow/received...            User
#
#   committer__user_view_type committer__site_admin        _dlt_load_id  \
# 0                    public                 False  1750393271.2874556
# 1                    public                 False  1750393271.2874556
# 2                    public                 False  1750393271.2874556
# 3                    public                 False  1750393271.2874556
# 4                    public                 False  1750393271.2874556
#
#           _dlt_id
# 0  xMYALiukkZ4NPQ
# 1  +ReRupwwV0r3pA
# 2  0hkd+G0yp8gDdg
# 3  Psyg40XK3sfqXA
# 4  HQYfluh6zK9xLA
#
# [5 rows x 61 columns]

# %%
cols = [
    'sha', 
    # 'node_id', 
    # 'commit__author__name', 
    # 'commit__author__email',
    'commit__author__date', 
    # 'commit__committer__name','commit__committer__email', 'commit__committer__date',
    'commit__message', 
    # 'commit__tree__sha','commit__tree__url','commit__url', 'commit__comment_count',
    # 'commit__verification__verified', 'commit__verification__reason',
    # 'commit__verification__signature', 'commit__verification__payload', 'commit__verification__verified_at', 'url', 'html_url', 
    # 'comments_url',
    'author__login', 
    # 'author__id', 'author__node_id', 'author__avatar_url','author__gravatar_id', 
    # 'author__url', 'author__html_url', 'author__followers_url', 'author__following_url', 'author__gists_url',
    # 'author__starred_url', 'author__subscriptions_url',
    # 'author__organizations_url', 'author__repos_url', 'author__events_url',
    # 'author__received_events_url', 'author__type', 'author__user_view_type',
    # 'author__site_admin', 'committer__login', 'committer__id',
    # 'committer__node_id', 'committer__avatar_url', 'committer__gravatar_id',
    # 'committer__url', 'committer__html_url', 'committer__followers_url',
    # 'committer__following_url', 'committer__gists_url',
    # 'committer__starred_url', 'committer__subscriptions_url',
    # 'committer__organizations_url', 'committer__repos_url',
    # 'committer__events_url', 'committer__received_events_url',
    # 'committer__type', 'committer__user_view_type', 'committer__site_admin',
    # '_dlt_load_id', '_dlt_id'
]

# %%
df[cols]
# Out:
#                                             sha      commit__author__date  \
# 0      7cc64d3bd174c00ca61cf1f746a48bf22bcaff54 2025-06-19 18:14:29+00:00
# 1      5cc2617b5f8eeb361e9e5b7f7084109188298714 2025-06-19 14:54:43+00:00
# 2      380a55e9bf8b6e49157f28f5dc4466d505cf1658 2025-06-19 13:53:53+00:00
# 3      b1ad7649f3dd5c8cb571e51e33e14266e3f4b1f0 2025-06-19 11:01:41+00:00
# 4      058b25d7c30a33787e5ea3e5ea7f071c036b4362 2025-06-19 03:34:52+00:00
# ...                                         ...                       ...
# 31656  3951357072668f330c1acaa1ad11aea2d89b81ee 2019-10-12 08:55:38+00:00
# 31657  cb24db899d07fbe83c734b0e18f7d9d618904b3b 2019-10-12 07:05:05+00:00
# 31658  bec67900fa9e0a4b2892d69f8f4968d3c344121b 2019-10-12 06:35:30+00:00
# 31659  ff6a1d151783d0e07aec2b40c6950817ef03f09f 2019-10-12 06:33:00+00:00
# 31660  1a374516deead12f0b737f4886c07be5b647d24a 2019-10-12 04:53:09+00:00
#
#                                          commit__message  author__login
# 0      docs(edge functions): document that sentry nee...      charislam
# 1      fix(docs): add more descriptive error message ...      charislam
# 2      docs: clarify that migrations must be applied ...   TJLSmith0831
# 3      db report (#36516)\n\n* release new charts to ...  fsansalvadore
# 4      chore: show org error message for longer (#36526)       kevcodez
# ...                                                  ...            ...
# 31656                   fat fingered typo for build:docs     kiwicopple
# 31657                       Adding netlify deploy config     kiwicopple
# 31658                                      Hiding signup     kiwicopple
# 31659                                Adding sign up form     kiwicopple
# 31660                                      Init monorepo     kiwicopple
#
# [31661 rows x 4 columns]

# %%
df['author__starred_url'][0]
# Out:
# 'https://api.github.com/users/charislam/starred{/owner}{/repo}'

# %% [markdown]
# ## normalization, data contract

# %% [markdown]
# ###
